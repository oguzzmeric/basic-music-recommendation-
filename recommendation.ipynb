# %%
import pandas as pd
import numpy as np

df = pd.read_csv("music_genre.csv")

df
# Out:
#        instance_id           artist_name  ... valence  music_genre
# 0          32894.0              Röyksopp  ...   0.759   Electronic
# 1          46652.0  Thievery Corporation  ...   0.531   Electronic
# 2          30097.0        Dillon Francis  ...   0.333   Electronic
# 3          62177.0              Dubloadz  ...   0.270   Electronic
# 4          24907.0           What So Not  ...   0.323   Electronic
# ...            ...                   ...  ...     ...          ...
# 50000      58878.0                 BEXEY  ...   0.330      Hip-Hop
# 50001      43557.0             Roy Woods  ...   0.113      Hip-Hop
# 50002      39767.0                Berner  ...   0.395      Hip-Hop
# 50003      57944.0             The-Dream  ...   0.354      Hip-Hop
# 50004      63470.0     Naughty By Nature  ...   0.765      Hip-Hop
#
# [50005 rows x 18 columns]

# %%
import numpy
input_list = [15,20,35,42,12,8]
max_value = numpy.argmax(input_list)
print(max_value)
# Out:
# 3

# %%
a = df["popularity"].value_counts()
a
# Out:
# 52.0    1316
# 54.0    1295
# 53.0    1286
# 50.0    1265
# 55.0    1250
#         ...
# 95.0       2
# 97.0       1
# 99.0       1
# 94.0       1
# 92.0       1
# Name: popularity, Length: 99, dtype: int64

# %%
a = df["popularity"]
max = np.argmax(a)

max
# Out:
# 26239

# %%
a = df["popularity"].value_counts().max()
a
# Out:
# 1316

# %%
a = len(df["music_genre"].value_counts())
b = df["music_genre"].value_counts()



a
b
# Out:
# Electronic     5000
# Anime          5000
# Jazz           5000
# Alternative    5000
# Country        5000
# Rap            5000
# Blues          5000
# Rock           5000
# Classical      5000
# Hip-Hop        5000
# Name: music_genre, dtype: int64

# %%
mg = str(input("music_genre"))
e = float(input("energy"))
po = float(input("popularity"))
tp = str(input("enter the tempo"))

def recc():
    print(len(df["track_name"][po>=df.popularity][df.energy>=e][df.music_genre==mg][df.tempo>=tp]))
    print(mg)
    print(e)
    print(po)
    print()
    return df["track_name"][df.popularity>=po][df.energy>=e][df.music_genre==mg][df.tempo>=tp][:10]
    

recc()
#hedef == otomazisayon
# Out:
# 261
# Hip-Hop
# 0.5
# 50.0
# 45005     Glory (From the Motion Picture Selma)
# 45008                               Molly Cyrus
# 45009    Feel It (feat. Rich Homie Quan, Lloyd)
# 45012                           Estoy Enamorado
# 45014                      Quiere Fumar - Remix
# 45018                                 Remind Me
# 45019                               White Label
# 45027                             Noche De Sexo
# 45028                                    Smooth
# 45029     Rabbit Run - From "8 Mile" Soundtrack
# Name: track_name, dtype: object

# %%
mg = str(input("music_genre"))
e = float(input("energy"))
po = float(input("popularity"))
tp = str(input("enter the tp"))


def recc():
    print(len(df["track_name"][df.popularity>=po][df.energy>=e][df.music_genre==mg][df.tempo>=tp]))
    print(mg)
    print(e)
    print(po)


    print(tp)

    return df[["track_name","popularity"]][df.popularity>=po][df.energy>=e][df.music_genre==mg][df.tempo>=tp][:10:]
    

recc()

#hedef == otomazisayon
#hh
#0.8
#50
#78
# Out:
# 14
# Blues
# 0.4
# 65.0
# 20
# C:\Users\HUAWEI~1\AppData\Local\Temp/ipykernel_14168/2463531120.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   return df[["track_name","popularity"]][df.popularity>=po][df.energy>=e][df.music_genre==mg][df.tempo>=tp][:10:]
#                                             track_name  popularity
# 30125                                In the Summertime        66.0
# 30543                                             Ohio        65.0
# 30875                                          Trouble        68.0
# 31856     (Your Love Keeps Lifting Me) Higher & Higher        69.0
# 31944                                  Bad To The Bone        65.0
# 32622  Feel Like Makin' Love - 2015 Remastered Version        66.0
# 32657                           Take The Money And Run        65.0
# 33065                              Gold on the Ceiling        66.0
# 33098                                      Eagle Birds        65.0
# ...

# %%
from collections import Counter
a = df[["track_name","popularity"]]#[df.tempo>=50]

# %%
recc()
# Out:
# 14
# Blues
# 0.4
# 65.0
# 20
# C:\Users\HUAWEI~1\AppData\Local\Temp/ipykernel_14168/2463531120.py:16: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   return df[["track_name","popularity"]][df.popularity>=po][df.energy>=e][df.music_genre==mg][df.tempo>=tp][:10:]
#                                             track_name  popularity
# 30125                                In the Summertime        66.0
# 30543                                             Ohio        65.0
# 30875                                          Trouble        68.0
# 31856     (Your Love Keeps Lifting Me) Higher & Higher        69.0
# 31944                                  Bad To The Bone        65.0
# 32622  Feel Like Makin' Love - 2015 Remastered Version        66.0
# 32657                           Take The Money And Run        65.0
# 33065                              Gold on the Ceiling        66.0
# 33098                                      Eagle Birds        65.0
# ...

# %%
# Out:
# <built-in method index of list object at 0x0000016237B35DC0>
